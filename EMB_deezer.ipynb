# %% [markdown]
# <a href="https://colab.research.google.com/github/migub/recommender-systems/blob/main/EMB_deezer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #pip install deezer-python

# %%
## 1. Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import deezer as deezer
import time
import os
import glob # file searching
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # New section

# %%
## 2. Load cleaned data from previous step
data = pd.read_csv("/content/drive/MyDrive/Recommender_Systems/cleaned_data.csv")

# Display basic info
data.info()
display(data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7558834 entries, 0 to 7558833
# Data columns (total 17 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   genre_id          int64
#  1   ts_listen         object
#  2   media_id          int64
#  3   album_id          int64
#  4   context_type      int64
#  5   release_date      object
#  6   platform_name     int64
#  7   platform_family   int64
#  8   media_duration    int64
#  9   listen_type       int64
#  10  user_gender       int64
#  11  user_id           int64
#  12  artist_id         int64
#  13  user_age          int64
#  14  is_listened       bool
#  15  listen_hour       int64
#  16  listen_dayofweek  int64
# dtypes: bool(1), int64(14), object(2)
# memory usage: 929.9+ MB
#    genre_id            ts_listen  media_id  album_id  context_type  \
# 0     25471  2016-12-01 13:00:15    222606     41774            12
# 1     25571  2016-11-30 22:25:35    250467     43941             0
# 2        16  2016-11-19 13:59:13    305197     48078             1
# 3         7  2016-11-26 09:21:38    900502     71521             0
# 4         7  2016-11-05 18:02:54    542335     71718             0
#
#   release_date  platform_name  platform_family  media_duration  listen_type  \
# 0   2004-07-04              1                0             223            0
# 1   2006-03-01              2                1             171            0
# 2   2014-07-14              2                1             149            1
# 3   2000-10-30              0                0             240            0
# 4   2008-02-15              0                0             150            0
#
#    user_gender  user_id  artist_id  user_age  is_listened  listen_hour  \
# 0            0     9241      55164        29        False           13
# 1            0    16547      55830        30         True           22
# 2            1     7665       2704        29         True           13
# 3            1     1580        938        30        False            9
# 4            1     1812       2939        24         True           18
#
#    listen_dayofweek
# 0                 3
# 1                 2
# 2                 5
# 3                 5
# 4                 5

# %% [markdown]
# Checking what type of data we can get via the deezer package.

# %%
client = deezer.Client()


# Testing deezer
track_id = 222606
track = client.get_track(track_id)

# Print track details
print(f"Title: {track.title}")
print(f"Artist: {track.artist.name}")
print(f"Album: {track.album.title}")
print(f"Duration: {track.duration} seconds")

# user_id = 16547
# user = client.get_user(user_id)
#
# # Print user details
# print(f"Gender: {user.gender}")
# print(f"Country: {user.country}")
# Out:
# Title: Seul au monde
# Artist: Malin Plaisir
# Album: Malin plaisir
# Duration: 223 seconds

# %% [markdown]
# While retrieval of track data works, user data is not as easily accessible.
#
# [I will continue to look into this, but at the moment, I'm not finding an easy solution. It could be an authentication problem, which could be circumvented by creating an app, but currently, no new app applications are being accepted by Deezer.]

# %%
# With improved error handling and chunking

def get_deezer_info(ids, entity_type):
    """
    Fetches information from the Deezer API for a given entity type (track or user).
    Skips entities with errors and enforces rate limiting.

    Args:
        ids (list): List of entity IDs (track IDs or user IDs).
        entity_type (str): Either 'track' or 'user'.

    Returns:
        pd.DataFrame: A DataFrame containing the requested information.
    """
    try:
        client = deezer.Client()
    except Exception as e:
        print(f"Failed to initialize Deezer client: {e}")
        return pd.DataFrame()

    data_list = []
    last_request_time = time.time()

    for entity_id in ids:
        # Rate limiting: Ensure at least 20ms between requests
        time_since_last_request = time.time() - last_request_time
        time.sleep(max(0, 0.02 - time_since_last_request))

        try:
            if entity_type == "track":
                track = client.get_track(entity_id)

                # Handle case where track is not found
                if track is None:
                    print(f"Track ID {entity_id} not found on Deezer.")
                    continue

                entity_info = {
                    "track_id": entity_id,
                    "title": track.title if track.title else "Unknown",
                    "artist_name": track.artist.name if track.artist else "Unknown",
                    "album_title": track.album.title if track.album else "Unknown",
                    "album_release_date": track.album.release_date if track.album else "Unknown",
                    "rank": track.rank,
                    "explicit_lyrics": track.explicit_lyrics,
                    "bpm": track.bpm
                }
                data_list.append(entity_info)

        except Exception as e:
            print(f"Error retrieving data for {entity_type} ID {entity_id}: {e}")

        last_request_time = time.time()

    return pd.DataFrame(data_list)

# %%
test = data.head(20)
print(test["media_id"])
# Out:
# 0     222606
# 1     250467
# 2     305197
# 3     900502
# 4     542335
# 5     542335
# 6     542335
# 7     542335
# 8     542335
# 9     542335
# 10    542335
# 11    542335
# 12    542341
# 13    542335
# 14    542335
# 15    542335
# 16    542335
# 17    542335
# 18    542335
# 19    542335
# Name: media_id, dtype: int64

# %%
# Testing on small dataset
track_info_df = get_deezer_info(test["media_id"].unique().tolist(), "track")  # Get track data
track_info_df = track_info_df.rename(columns={"track_id": "media_id"})  # Rename column for merging
test2 = test.merge(track_info_df, on="media_id", how="left")  # Merge retrieved track data

# user_info_df = get_deezer_info((test["user_id"].unique()).tolist(), "user")
# user_info_df = user_info_df.rename(columns={"id": "user_id"})  # Rename column for merging
#test = test.merge(user_info_df, on="user_id", how="left")  # Merge retrieved track data
# print(user_info_df)
# print(test)

# %%
test2.head()
# Out:
#    genre_id            ts_listen  media_id  album_id  context_type  \
# 0     25471  2016-12-01 13:00:15    222606     41774            12
# 1     25571  2016-11-30 22:25:35    250467     43941             0
# 2        16  2016-11-19 13:59:13    305197     48078             1
# 3         7  2016-11-26 09:21:38    900502     71521             0
# 4         7  2016-11-05 18:02:54    542335     71718             0
#
#   release_date  platform_name  platform_family  media_duration  listen_type  \
# 0   2004-07-04              1                0             223            0
# 1   2006-03-01              2                1             171            0
# 2   2014-07-14              2                1             149            1
# 3   2000-10-30              0                0             240            0
# 4   2008-02-15              0                0             150            0
#
#    ...  is_listened  listen_hour  listen_dayofweek               title  \
# 0  ...        False           13                 3       Seul au monde
# 1  ...         True           22                 2       You're not ok
# 2  ...         True           13                 5              Samuel
# 3  ...        False            9                 5     Mujer Amiga Mia
# 4  ...         True           18                 5  Mr. Tambourine Man
#
#        artist_name                         album_title  album_release_date  \
# 0    Malin Plaisir                       Malin plaisir          2004-07-04
# 1          SoldouT           Stop talking / dead tapes          2006-03-01
# 2       René Aubry                             Dérives          2014-07-14
# 3  Eros Ramazzotti       Estilolibre (Spanish Version)          2000-10-30
# 4        The Byrds  Collections - The Byrds Play Dylan          2008-02-15
#
#      rank explicit_lyrics    bpm
# 0    1711           False  100.1
# 1   70929           False  160.2
# 2  115098           False   90.1
# 3  103778           False  124.9
# 4  407879           False  120.5
#
# [5 rows x 24 columns]

# %% [markdown]
# # Deezer scraping

# %% [markdown]
# Now implementing the above for the whole training dataset and saving the resulting df for sharing with colleagues.

# %%
# Load media IDs
media_ids = data["media_id"].unique().tolist()

# Split media_ids into chunks of 100
chunk_size = 100
media_id_chunks = [media_ids[i:i + chunk_size] for i in range(0, len(media_ids), chunk_size)]

# Step 1: Process each chunk and save separately, skipping existing chunks
for i, chunk in enumerate(media_id_chunks):
    chunk_file = f"/content/drive/MyDrive/Recommender_Systems/chunks/track_info_chunk_{i}.csv"

    # Skip if chunk file already exists (no overwriting)
    if os.path.exists(chunk_file):
        print(f"Chunk {i} already exists. Skipping...")
        continue

    print(f"Processing chunk {i}...")
    track_info_df_chunk = get_deezer_info(chunk, "track")

    if not track_info_df_chunk.empty:
        track_info_df_chunk.to_csv(chunk_file, index=False)
        print(f"Saved: {chunk_file}")
    else:
        print(f"Skipping saving {chunk_file} (empty DataFrame).")

print("All chunks processed and saved!!!")
# Out:
# Chunk 0 already exists. Skipping...
# Chunk 1 already exists. Skipping...
# Chunk 2 already exists. Skipping...
# Processing chunk 3...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_3.csv
# Processing chunk 4...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_4.csv
# Processing chunk 5...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_5.csv
# Processing chunk 6...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_6.csv
# Processing chunk 7...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_7.csv
# Processing chunk 8...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_8.csv
# Processing chunk 9...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_9.csv
# Processing chunk 10...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_10.csv
# Processing chunk 11...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_11.csv
# Processing chunk 12...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_12.csv
# Processing chunk 13...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_13.csv
# Processing chunk 14...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_14.csv
# Processing chunk 15...
# Error retrieving data for track ID 90072359: {'error': {'type': 'DataException', 'message': 'no data', 'code': 800}}
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_15.csv
# Processing chunk 16...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_16.csv
# Processing chunk 17...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_17.csv
# Processing chunk 18...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_18.csv
# Processing chunk 19...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_19.csv
# Processing chunk 20...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_20.csv
# Processing chunk 21...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_21.csv
# Processing chunk 22...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_22.csv
# Processing chunk 23...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_23.csv
# Processing chunk 24...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_24.csv
# Processing chunk 25...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_25.csv
# Processing chunk 26...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_26.csv
# Processing chunk 27...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_27.csv
# Processing chunk 28...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_28.csv
# Processing chunk 29...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_29.csv
# Processing chunk 30...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_30.csv
# Processing chunk 31...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_31.csv
# Processing chunk 32...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_32.csv
# Processing chunk 33...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_33.csv
# Processing chunk 34...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_34.csv
# Processing chunk 35...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_35.csv
# Processing chunk 36...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_36.csv
# Processing chunk 37...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_37.csv
# Processing chunk 38...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_38.csv
# Processing chunk 39...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_39.csv
# Processing chunk 40...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_40.csv
# Processing chunk 41...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_41.csv
# Processing chunk 42...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_42.csv
# Processing chunk 43...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_43.csv
# Processing chunk 44...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_44.csv
# Processing chunk 45...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_45.csv
# Processing chunk 46...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_46.csv
# Processing chunk 47...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_47.csv
# Processing chunk 48...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_48.csv
# Processing chunk 49...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_49.csv
# Processing chunk 50...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_50.csv
# Processing chunk 51...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_51.csv
# Processing chunk 52...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk

# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_1993.csv
# Processing chunk 1994...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_1994.csv
# Processing chunk 1995...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_1995.csv
# Processing chunk 1996...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_1996.csv
# Processing chunk 1997...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_1997.csv
# Processing chunk 1998...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_1998.csv
# Processing chunk 1999...
# Saved: /content/drive/MyDrive/Recommender_Systems/track_info_chunk_1999.csv
# Processing chunk 2000...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-d9c1ebcb3a7e> in <cell line: 0>()
#      16
#      17     print(f"Processing chunk {i}...")
# ---> 18     track_info_df_chunk = get_deezer_info(chunk, "track")
#      19
#      20     if not track_info_df_chunk.empty:
#
# <ipython-input-27-299e31e196b5> in get_deezer_info(ids, entity_type)
#      29         try:
#      30             if entity_type == "track":
# ---> 31                 track = client.get_track(entity_id)
#      32
#      33                 # Handle case where track is not found
#
# /usr/local/lib/python3.11/dist-packages/deezer/client.py in get_track(self, track_id)
#     338         :returns: a :class:`~deezer.Track` object
#     339         """
# --> 340         return self.request("GET", f"track/{track_id}")
#     341
#     342     def get_user(self, user_id: int | None = None) -> User:
#
# /usr/local/lib/python3.11/dist-packages/deezer/client.py in request(self, method, path, parent, resource_type, resource_id, paginate_list, **kwargs)
#     153         :param paginate_list: Whether to wrap list into a pagination object.
#     154         """
# --> 155         response = super().request(
#     156             method,
#     157             path,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     823             extensions=extensions,
#     824         )
# --> 825         return self.send(request, auth=auth, follow_redirects=follow_redirects)
#     826
#     827     @contextmanager
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     912         auth = self._build_request_auth(request, auth)
#     913
# --> 914         response = self._send_handling_auth(
#     915             request,
#     916             auth=auth,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     940
#     941             while True:
# --> 942                 response = self._send_handling_redirects(
#     943                     request,
#     944                     follow_redirects=follow_redirects,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     977                 hook(request)
#     978
# --> 979             response = self._send_single_request(request)
#     980             try:
#     981                 for hook in self._event_hooks["response"]:
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_single_request(self, request)
#    1012
#    1013         with request_context(request=request):
# -> 1014             response = transport.handle_request(request)
#    1015
#    1016         assert isinstance(response.stream, SyncByteStream)
#
# /usr/local/lib/python3.11/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     248         )
#     249         with map_httpcore_exceptions():
# --> 250             resp = self._pool.handle_request(req)
#     251
#     252         assert isinstance(resp.stream, typing.Iterable)
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     254
#     255             self._close_connections(closing)
# --> 256             raise exc from None
#     257
#     258         # Return the response. Note that in this case we still have to manage
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     234                 try:
#     235                     # Send the request on the assigned connection.
# --> 236                     response = connection.handle_request(
#     237                         pool_request.request
#     238                     )
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#     101             raise exc
#     102
# --> 103         return self._connection.handle_request(request)
#     104
#     105     def _connect(self, request: Request) -> NetworkStream:
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     134                 with Trace("response_closed", logger, request) as trace:
#     135                     self._response_closed()
# --> 136             raise exc
#     137
#     138     # Sending the request...
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     104                     headers,
#     105                     trailing_data,
# --> 106                 ) = self._receive_response_headers(**kwargs)
#     107                 trace.return_value = (
#     108                     http_version,
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_response_headers(self, request)
#     175
#     176         while True:
# --> 177             event = self._receive_event(timeout=timeout)
#     178             if isinstance(event, h11.Response):
#     179                 break
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     215
#     216             if event is h11.NEED_DATA:
# --> 217                 data = self._network_stream.read(
#     218                     self.READ_NUM_BYTES, timeout=timeout
#     219                 )
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_backends/sync.py in read(self, max_bytes, timeout)
#     126         with map_exceptions(exc_map):
#     127             self._sock.settimeout(timeout)
# --> 128             return self._sock.recv(max_bytes)
#     129
#     130     def write(self, buffer: bytes, timeout: float | None = None) -> None:
#
# /usr/lib/python3.11/ssl.py in recv(self, buflen, flags)
#    1293                     "non-zero flags not allowed in calls to recv() on %s" %
#    1294                     self.__class__)
# -> 1295             return self.read(buflen)
#    1296         else:
#    1297             return super().recv(buflen, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1166                 return self._sslobj.read(len, buffer)
#    1167             else:
# -> 1168                 return self._sslobj.read(len)
#    1169         except SSLError as x:
#    1170             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# Step 2: Combine all chunk files (Separate Step)
output_file = "/content/drive/MyDrive/Recommender_Systems/track_info_deezer.csv"
print("Combining all chunk files into final dataset...")

# Find all chunk CSV files
chunk_files = sorted(glob.glob("/content/drive/MyDrive/Recommender_Systems/chunks/track_info_chunk_*.csv"))

# Append each chunk to the final output file (step-by-step)
header_written = False
for chunk_file in chunk_files:
    chunk_df = pd.read_csv(chunk_file)

    # Append to final CSV (write header only for first chunk)
    chunk_df.to_csv(output_file, mode="w" if not header_written else "a", header=not header_written, index=False)
    header_written = True  # Ensure header is only written once

print(f"Final dataset saved: {output_file}")

# %%
track_info_df = track_info_df.rename(columns={"track_id": "media_id"})  # Rename column for merging

# %%
# Save the DataFrame 'track_info' to Google Drive.
track_info_df.to_csv("/content/drive/MyDrive/Recommender_Systems/track_info_deezer.csv", index=False)

# %%
data2 = data.merge(track_info_df, on="media_id", how="left")  # Merge retrieved track data
